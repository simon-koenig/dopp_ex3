# %% [markdown]
# # Preprocessing of understat_per_game.csv + Getting first insights

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import file
with open('./data/understat_per_game.csv') as f:
    df = pd.read_csv(f)

# %%
df.head(10)
# Out:
#        league  year h_a       xG       xGA     npxG     npxGA  deep  \
# 0  Bundesliga  2014   h  2.57012  1.198420  2.57012  1.198420     5
# 1  Bundesliga  2014   a  1.50328  1.307950  1.50328  1.307950    10
# 2  Bundesliga  2014   h  1.22987  0.310166  1.22987  0.310166    13
# 3  Bundesliga  2014   a  1.03519  0.203118  1.03519  0.203118     6
# 4  Bundesliga  2014   h  3.48286  0.402844  3.48286  0.402844    23
# 5  Bundesliga  2014   a  3.46966  0.821798  3.46966  0.821798    27
# 6  Bundesliga  2014   h  2.69879  0.443178  2.69879  0.443178    14
# 7  Bundesliga  2014   h  2.49826  0.000000  1.74049  0.000000    16
# 8  Bundesliga  2014   a  1.20470  0.648384  1.20470  0.648384     5
# 9  Bundesliga  2014   h  2.64367  0.942884  1.88605  0.942884    11
#
#    deep_allowed  scored  ...  ppda_coef  ppda_att ppda_def oppda_coef  \
# 0             4       2  ...   9.625000       231       24  21.850000
# 1             1       1  ...   4.756098       195       41  17.695652
# ...

# %%
df.columns
# Out:
# Index(['league', 'year', 'h_a', 'xG', 'xGA', 'npxG', 'npxGA', 'deep',
#        'deep_allowed', 'scored', 'missed', 'xpts', 'result', 'date', 'wins',
#        'draws', 'loses', 'pts', 'npxGD', 'ppda_coef', 'ppda_att', 'ppda_def',
#        'oppda_coef', 'oppda_att', 'oppda_def', 'team', 'xG_diff', 'xGA_diff',
#        'xpts_diff'],
#       dtype='object')

# %%
# plot histogramms of all columns
fig,axs = plt.subplots(len(df.columns[4:])//3,3,figsize=(12,20))
i = 4
for triaxis in axs: 
    for ax in triaxis:
        if df.columns[i] == 'result' or df.columns[i] == 'date' or df.columns[i] == 'team':
            i+=1
            continue
        df.hist(column=df.columns[i],ax=ax)
        i+=1
